# %% [markdown]
# # Feature Engineering(Handling Missing values)

# %% [markdown]
# ## handling for categorical data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## reading the dataset
data = pd.read_csv(r'C:\Users\P nageswararao\OneDrive\Desktop\hr_cleaned.csv')

# %%
data
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
## dataset information 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    19158 non-null  object
#  1   city_development_index  19158 non-null  float64
#  2   gender                  14650 non-null  object
#  3   relevent_experience     19158 non-null  object
#  4   enrolled_university     18772 non-null  object
#  5   education_level         18698 non-null  object
#  6   major_discipline        16345 non-null  object
#  7   experience              19158 non-null  int64
#  8   company_size            19158 non-null  object
#  9   company_type            13018 non-null  object
#  10  last_new_job            19158 non-null  int64
#  11  training_hours          19158 non-null  int64
#  12  target                  19158 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.9+ MB

# %%
## checking for missing values
data.isnull().sum()
# Out:
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                   0
# company_size                 0
# company_type              6140
# last_new_job                 0
# training_hours               0
# target                       0
# dtype: int64

# %% [markdown]
# ### Replacing missing value with RANDOM VALUE

# %%
data['gender'] = data['gender'].replace(np.nan,'male')

# %%
data['gender'].isnull().sum()
# Out:
# 0

# %%
data['enrolled_university'] = data['enrolled_university'].replace(np.nan,'Full time course')

# %%
data['enrolled_university'].isnull().sum()
# Out:
# 0

# %%
data['education_level'] = data['education_level'].replace(np.nan,'Graduate')

# %%
data['education_level'].isnull().sum()
# Out:
# 0

# %%
data['major_discipline'] = data['major_discipline'].replace(np.nan,'STEM')

# %%
data['major_discipline'].isnull().sum()
# Out:
# 0

# %%
data['company_type']  = data['company_type'].replace(np.nan,'Small & Medium-org')

# %%
data['company_type'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# training_hours            0
# target                    0
# dtype: int64

# %% [markdown]
# ### Replacing missing values using FORWARD FILLING

# %%
data['gender'] = data['gender'].ffill()

# %%
data['enrolled_university'] = data['enrolled_university'].ffill()

# %%
data['education_level'] = data['education_level'].ffill()

# %%
data['major_discipline'] = data['major_discipline'].ffill()

# %%
data['company_type'] = data['company_type'].ffill()

# %%
data.isnull().sum()
# Out:
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# training_hours            0
# target                    0
# dtype: int64

# %% [markdown]
# ### replacing missing values with BACKWARD FILLING

# %%
data['gender'] = data['gender'].bfill()

# %%
data['enrolled_university'] = data['enrolled_university'].bfill()

# %%
data['education_level'] = data['education_level'].bfill()

# %%
data['major_discipline'] = data['major_discipline'].bfill()

# %%
data['company_type'] = data['company_type'].bfill()

# %%
data.isnull().sum()
# Out:
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# training_hours            0
# target                    0
# dtype: int64

# %% [markdown]
# ### Replacing missing values with MODE

# %%
data['gender'] = data['gender'].replace(np.nan,data['gender'].mode)

# %%
data['enrolled_university'] = data['enrolled_university'].replace(np.nan,data['enrolled_university'].mode)

# %%
data['education_level'] = data['education_level'].replace(np.nan,data['education_level'].mode)

# %%
data['major_discipline'] = data['major_discipline'].replace(np.nan,data['major_discipline'].mode)

# %%
data['company_type']  = data['company_type'].replace(np.nan,data['company_type'].mode)

# %%
data
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624   male   No relevent experience
# 3      city_115                   0.789   male   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855   male   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %% [markdown]
# ### dropping  NaN containing rows

# %%
data.dropna(axis=0)
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624   male   No relevent experience
# 3      city_115                   0.789   male   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855   male   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...
